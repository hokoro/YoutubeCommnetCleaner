# %%
import pandas as pd

# %%
df = pd.read_excel('/content/AI_Wave_1.xlsx')

# %%
df
# Out:
#        연령  성별    상황키워드 감정_대분류       감정_소분류  \
# 0     청소년  남성  학업 및 진로     기쁨         감사하는
# 1     청소년  남성  학업 및 진로     기쁨         감사하는
# 2     청소년  남성  학업 및 진로     기쁨         감사하는
# 3     청소년  남성  학업 및 진로     기쁨         감사하는
# 4     청소년  남성  학업 및 진로     기쁨         감사하는
# ...   ...  ..      ...    ...          ...
# 9995   노년  남성       재정     슬픔      환멸을 느끼는
# 9996   노년  남성    건강,죽음     상처         충격받은
# 9997   노년  남성       재정     불안        걱정스러운
# 9998   노년  여성    건강,죽음     불안          두려운
# 9999   노년  남성       재정     당황  남의 시선을 의식하는
#
#                                                   사람문장1  \
# 0             오늘 반장 선거에서 내가 반장이 됐어! 친구들이 날 믿어줘서 너무 고맙다.
# 1                  오늘 시험에 친구가 알려준 문제가 나왔어. 결과가 좋아서 기쁘다.
# 2             오늘 대학 합격 통지를 받았어. 엄마가 너무 기뻐하는데 나는 눈물이 났어.
# 3       오늘 졸업식인데 선생님께서 아프셔서 오지 못하셨어. 그동안 감사하다는 말도 못했는데.
# 4              나 올림피아드에서 금상 받았어! 그동안 고생이 헛되지 않아서 너무 기뻐.
# ...                                                 ...
# ...

# %%
Data_df = pd.DataFrame(columns=["sentence","label"])

# %%
Data_df['sentence'] = df['사람문장1']

# %%
Data_df['label'] = df['감정_대분류']

# %%
Data_df
# Out:
#                                                sentence label
# 0             오늘 반장 선거에서 내가 반장이 됐어! 친구들이 날 믿어줘서 너무 고맙다.    기쁨
# 1                  오늘 시험에 친구가 알려준 문제가 나왔어. 결과가 좋아서 기쁘다.    기쁨
# 2             오늘 대학 합격 통지를 받았어. 엄마가 너무 기뻐하는데 나는 눈물이 났어.    기쁨
# 3       오늘 졸업식인데 선생님께서 아프셔서 오지 못하셨어. 그동안 감사하다는 말도 못했는데.    기쁨
# 4              나 올림피아드에서 금상 받았어! 그동안 고생이 헛되지 않아서 너무 기뻐.    기쁨
# ...                                                 ...   ...
# 9995               소득이 너무 적어서 제대로 된 노후 대책을 할 수가 없어 힘들어.    슬픔
# 9996      요즘 두통이 잦았는데 결국 이런 일이 생겼네. 난 건강한 줄 알았는데 충격받았어.    상처
# 9997  친구가 돈이 행복의 전부가 아니라고 하더니 노후 준비를 전혀 안 한 거야. 어휴 정...    불안
# 9998                   아들이 갑자기 찾아왔는데 손자가 희귀병이래. 너무 두려워.    불안
# 9999            친구들에게는 자식이 선물해 줬다고 했지만 사실은 다 내가 구입한 거야.    당황
#
# [10000 rows x 2 columns]

# %%
for index in range(Data_df.index.stop):
  Data_df.loc[(Data_df['label'] == "기쁨"), 'label'] = 0  #기쁨 => 0
  Data_df.loc[(Data_df['label'] == "슬픔"), 'label'] = 1  #슬픔 => 1
  Data_df.loc[(Data_df['label'] == "분노"), 'label'] = 2  #분노 => 2
  Data_df.loc[(Data_df['label'] == "불안"), 'label'] = 3  #불안 => 3
  Data_df.loc[(Data_df['label'] == "상처"), 'label'] = 4  #상처 => 4
  Data_df.loc[(Data_df['label'] == "당황"), 'label'] = 5  #당황 => 5

# %%
Data_df
# Out:
#                                                sentence label
# 0             오늘 반장 선거에서 내가 반장이 됐어! 친구들이 날 믿어줘서 너무 고맙다.     0
# 1                  오늘 시험에 친구가 알려준 문제가 나왔어. 결과가 좋아서 기쁘다.     0
# 2             오늘 대학 합격 통지를 받았어. 엄마가 너무 기뻐하는데 나는 눈물이 났어.     0
# 3       오늘 졸업식인데 선생님께서 아프셔서 오지 못하셨어. 그동안 감사하다는 말도 못했는데.     0
# 4              나 올림피아드에서 금상 받았어! 그동안 고생이 헛되지 않아서 너무 기뻐.     0
# ...                                                 ...   ...
# 9995               소득이 너무 적어서 제대로 된 노후 대책을 할 수가 없어 힘들어.     1
# 9996      요즘 두통이 잦았는데 결국 이런 일이 생겼네. 난 건강한 줄 알았는데 충격받았어.     4
# 9997  친구가 돈이 행복의 전부가 아니라고 하더니 노후 준비를 전혀 안 한 거야. 어휴 정...     3
# 9998                   아들이 갑자기 찾아왔는데 손자가 희귀병이래. 너무 두려워.     3
# 9999            친구들에게는 자식이 선물해 줬다고 했지만 사실은 다 내가 구입한 거야.     5
#
# [10000 rows x 2 columns]

# %%
df2 = pd.read_csv('/content/word.txt', sep = "\n")

# %%
df2
# Out:
#                                                      욕설
# 0                                             좌배 까는건 ㅇㅂ
# 1           개소리야 니가 빨갱이를 옹호하고 드루킹을 ㅇㅇ짓이라고 말못해서 삐진거야 빨갱아
# 2                                    애새끼가 초딩도 아니고 ㅋㅋㅋㅋ
# 3     731부대의 후예라 그런지 가학적인 아이디어는 세계최고임 이래서 애교만 떨어도 돈 ...
# 4                                               재앙이한건햇노
# ...                                                 ...
# 1695                                찐따 특: 주류까면 있어보이는줄 앎
# 1696  ㅋㅋㅋㅋㅋㅋ 부모 욕 먹으니 바로 꿈틀대쥬? 거지 논하는데 자칭 미래가 없는 너가 ...
# 1697  ㅇㅈ 솔직히 틀딱들이 박정희 좋아하고 보수 지지하는것도 무슨 신념이 있어서라기보단 ...
# 1698               찐따라기보단 유행하는클론옷이지 ㅎㅎ 찐따는 시장표애미가사온패딩입음
# 1699  용접이 무슨 앉아서 지지기만 하면 되는 건 줄 아나본뎅, 실상 그게 아니거덩. 응용...
#
# [1700 rows x 1 columns]

# %%
Data_df2 = pd.DataFrame(columns=["sentence","label"])

# %%
Data_df2['sentence']=df2['욕설']

# %%
for index in range(df2.index.stop):
  Data_df2['label']="6"

# %%
Data_df2
# Out:
#                                                sentence label
# 0                                             좌배 까는건 ㅇㅂ     6
# 1           개소리야 니가 빨갱이를 옹호하고 드루킹을 ㅇㅇ짓이라고 말못해서 삐진거야 빨갱아     6
# 2                                    애새끼가 초딩도 아니고 ㅋㅋㅋㅋ      6
# 3     731부대의 후예라 그런지 가학적인 아이디어는 세계최고임 이래서 애교만 떨어도 돈 ...     6
# 4                                               재앙이한건햇노     6
# ...                                                 ...   ...
# 1695                                찐따 특: 주류까면 있어보이는줄 앎     6
# 1696  ㅋㅋㅋㅋㅋㅋ 부모 욕 먹으니 바로 꿈틀대쥬? 거지 논하는데 자칭 미래가 없는 너가 ...     6
# 1697  ㅇㅈ 솔직히 틀딱들이 박정희 좋아하고 보수 지지하는것도 무슨 신념이 있어서라기보단 ...     6
# 1698               찐따라기보단 유행하는클론옷이지 ㅎㅎ 찐따는 시장표애미가사온패딩입음     6
# 1699  용접이 무슨 앉아서 지지기만 하면 되는 건 줄 아나본뎅, 실상 그게 아니거덩. 응용...     6
#
# [1700 rows x 2 columns]

# %%
Data_df=Data_df.append(Data_df2)

# %%
Data_df
# Out:
#                                                sentence label
# 0             오늘 반장 선거에서 내가 반장이 됐어! 친구들이 날 믿어줘서 너무 고맙다.     0
# 1                  오늘 시험에 친구가 알려준 문제가 나왔어. 결과가 좋아서 기쁘다.     0
# 2             오늘 대학 합격 통지를 받았어. 엄마가 너무 기뻐하는데 나는 눈물이 났어.     0
# 3       오늘 졸업식인데 선생님께서 아프셔서 오지 못하셨어. 그동안 감사하다는 말도 못했는데.     0
# 4              나 올림피아드에서 금상 받았어! 그동안 고생이 헛되지 않아서 너무 기뻐.     0
# ...                                                 ...   ...
# 1695                                찐따 특: 주류까면 있어보이는줄 앎     6
# 1696  ㅋㅋㅋㅋㅋㅋ 부모 욕 먹으니 바로 꿈틀대쥬? 거지 논하는데 자칭 미래가 없는 너가 ...     6
# 1697  ㅇㅈ 솔직히 틀딱들이 박정희 좋아하고 보수 지지하는것도 무슨 신념이 있어서라기보단 ...     6
# 1698               찐따라기보단 유행하는클론옷이지 ㅎㅎ 찐따는 시장표애미가사온패딩입음     6
# 1699  용접이 무슨 앉아서 지지기만 하면 되는 건 줄 아나본뎅, 실상 그게 아니거덩. 응용...     6
#
# [11700 rows x 2 columns]

# %%
  new_df=Data_df.sample(frac=1).reset_index(drop=True)

# %%
new_df
# Out:
#                                            sentence label
# 0          뭐래 븅신이 ㅋㅋㅋㅋㅋㅋ 통계가 뜬건데 니 뇌피셜이 아니라 통계라고 ^^     6
# 1          애인은 우리가 싸우는 이유를 전부 내 탓으로 돌리는데 정말 이해가 안가.     2
# 2       오늘 시험 시간에 다른 친구가 컨닝하는 것을 보고 놀랐어. 그리고 당황스러워.     5
# 3      기숙사에 있던 아들을 오랜만에 봤는데 걱정될 정도로 살이 너무 빠져서 당황했어.     3
# 4                   재미 삼아 복권을 구입한 회사 동료가 삼 등에 당첨됐어!     0
# ...                                             ...   ...
# 11695                       만성질환이 있었지만 살 만큼 살은거 같애.     0
# 11696            형이랑 같이 길을 뛰어가다가 돌에 걸려서 넘어져서 부끄러웠어.     5
# 11697           딸이 개인교습을 받고 싶어 하는데 해줄 수가 없어서 너무 슬퍼.     1
# 11698            학교에서 아이가 성적표를 받아왔어. 내 예상보다 낮은 등수야.     5
# 11699                                    알겠다 이 미친놈아     6
#
# [11700 rows x 2 columns]
